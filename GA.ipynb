# %%
from utils import process,make_sources,rows,find_needed_for_lists,find
import random

# %%
sources = make_sources()
storage = {}
for row in rows:
    storage[row['Name']] = 0
storage['wheat']=1
storage['corn']=1
storage['soybean']=1

# %%
goal = [
    {
        "bread":1,
        "milk":3
    },
    {
        "egg":1,
        'cream':3
    }
]

# %%
find_needed_for_lists(['bread','milk'])
# Out:
# ['wheat', 'wheat', 'wheat', 'cow feed', 'corn', 'soybean', 'soybean']

# %%
process(find_needed_for_lists(['bread','milk']),storage,sources)
# Out:
# {'time': 1800,
#  'storage': {'wheat': 4,
#   'egg': 0,
#   'corn': 1,
#   'bread': 0,
#   'chicken feed': 0,
#   'soybean': 0,
#   'cow feed': 1,
#   'milk': 0,
#   'cream': 0,
#   'sugarcane': 0,
#   'corn bread': 0,
#   'brown sugar': 0,
#   'popcorn': 0,
#   'carrot': 0,
#   'butter': 0,
#   'pancake': 0,
#   'pig feed': 0,
#   'bacon': 0,
#   'cookie': 0,
#   'bacon and eggs': 0,
#   'cheese': 0,
#   'indigo': 0,
#   'white sugar': 0,
#   'carrot pie': 0,
#   'pumpkin': 0,
#   'pumpkin pie': 0,
#   'apple': 0,
#   'sheep feed': 0,
#   'wool': 0,
#   'buttered popcorn': 0,
#   'sweater': 0,
#   'cotton': 0,
#   'bacon pie': 0,
#   'syrup': 0,
#   'cotton fabric': 0,
#   'hamburger': 0,
#   'raspberry': 0,
#   'raspberry muffin': 0,
#   'blue woolly hat': 0,
#   'cotton shirt': 0,
#   'blue sweater': 0,
#   'carrot cake': 0,
#   'wooly chaps': 0,
#   'cherry': 0,
#   'cream cake': 0,
#   'red berry cake': 0,
#   'cheesecake': 0,
#   'silver ore': 0,
#   'gold ore': 0,
# ...
